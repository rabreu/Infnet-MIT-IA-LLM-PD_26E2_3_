# %% [markdown]
# ## _Scrapper_ | Site Anvisa de Alertas e Notificações

# %%
from pathlib import Path

DATASET_DIR = '/dataset'

ROOT_DIR = Path().resolve().__str__()
DATASET_PATH = ROOT_DIR + DATASET_DIR
DATASET_FILENAME = 'Anvisa_Alertas_2026-01-01_2026-06-19_.csv'
DATASET_FILEPATH = Path(ROOT_DIR + DATASET_DIR + '/' + DATASET_FILENAME)
Path.mkdir(Path(DATASET_PATH), parents=True, exist_ok=True)

# %%
from bs4 import BeautifulSoup
import re

url = "https://antigo.anvisa.gov.br/alertas/-/buscar?p_p_id=anvisabuscaavancada_WAR_anvisabuscaavancadaportlet&keywords=&dataInicial=01/01/2016&dataFinal=19/06/2026&categoryIds=34506&categoryIds=5396434&categoryIds=5396432&categoryIds=34509&categoryIds=34510&categoryIds=34511"
page = "&pagina="
url_paginated = url+page

def scrap(url: str):
    scrapper = cs.create_scraper()
    res = scrapper.get(url)
    return res, BeautifulSoup(res.text, "html.parser")

res, soup = scrap(url)

alertas = soup.find_all(name='p', attrs={'class': 'titulo'})

# URLs
links = [alerta.find('a', href=True)['href'] for alerta in alertas]

# Titulo
titulos = [alerta.text.strip() for alerta in alertas]

# Data
def data(soup: BeautifulSoup):
    datas = soup.find_all('p', attrs={'class': 'data'})
    datas = [data.text.strip() for data in datas]
    datas = filter(lambda d: re.search(r"[a-z]", d) is None, datas)
    datas = list(datas)
    return datas

datas = data(soup)

# Paginação
pagination = soup.find_all(name='li', attrs={'class': 'pagination-control'})

# %%
last_page = max([int(page.find('a')['data-pagination'] if page.find('a')['data-pagination'] != '' else '0') for page in pagination])
next_page = 1

# %%
while next_page < last_page:
    next_page = next_page + 1
    res, soup = scrap(url_paginated+str(next_page))

    if res.status_code != 200:
        error_msg = f"Response code: {res.status_code} | Reason: {res.reason} | URL: {url_paginated+str(next_page)}"
        print(f"Response code: {res.status_code} | Reason: {res.reason} | URL: {url_paginated+str(next_page)}")
        links.append(error_msg)
        titulos.append(error_msg)
        datas.append(error_msg)
    else:
        alertas = soup.find_all(name='p', attrs={'class': 'titulo'})
        _titulos = [alerta.text.strip() for alerta in alertas]
        titulos.extend(_titulos)

# %%
import pandas as pd

df = pd.DataFrame(data={'titulo': titulos, 'data': datas, 'url': links})
df
# Out:
#                                                  titulo        data  \
# 0     Alerta 5265 (Tecnovigilância) - Comunicado da ...  16/06/2026
# 1     Alerta 5264 (Tecnovigilância) - Comunicado da ...  16/06/2026
# 2     Alerta 5263 (Tecnovigilância) - Comunicado da ...  16/06/2026
# 3     Alerta 5262 (Tecnovigilância) - Comunicado da ...  16/06/2026
# 4     Alerta 5261 (Tecnovigilância) - Comunicado da ...  16/06/2026
# ...                                                 ...         ...
# 3514  Alerta 1789 Atualizado (Tecnovigilância) - GE ...  13/01/2016
# 3515                                        Alerta 1788  12/01/2016
# 3516                                        Alerta 1787  12/01/2016
# 3517                                        Alerta 1780  06/01/2016
# 3518                                        Alerta 1779  06/01/2016
#
#                                                     url
# 0     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 1     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 2     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 4     http://antigo.anvisa.gov.br/informacoes-tecnic...
# ...                                                 ...
# 3514  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3515  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3516  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3517  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3518  http://antigo.anvisa.gov.br/informacoes-tecnic...
#
# [3519 rows x 3 columns]

# %%
df.to_csv(DATASET_FILEPATH, index=False, encoding='utf-8')

# %%
links = [alerta.find('a', href=True)['href'] for alerta in alertas]
datas = soup.find_all('p', attrs={'class': 'data'})

# %%
import cloudscraper as cs

scrapper = cs.create_scraper()

def retrieve_content(_url: str):
    res = scrapper.get(_url)

    if res.status_code != 200:
        print(f"Response code: {res.status_code} | URL: {_url}")
        return res.status_code

    html = res.text
    soup = BeautifulSoup(html, "html.parser")
    content = soup.find('div', attrs={'class':'journal-content-article'})
    return content.text

c_content = [retrieve_content(url) for url in df['url']]

# %%
df = pd.DataFrame(data={'titulo': df['titulo'], 'url': df['url'], 'content': c_content})
df
# Out:
#                                                  titulo  \
# 0     Alerta 5265 (Tecnovigilância) - Comunicado da ...
# 1     Alerta 5264 (Tecnovigilância) - Comunicado da ...
# 2     Alerta 5263 (Tecnovigilância) - Comunicado da ...
# 3     Alerta 5262 (Tecnovigilância) - Comunicado da ...
# 4     Alerta 5261 (Tecnovigilância) - Comunicado da ...
# ...                                                 ...
# 3514  Alerta 1789 Atualizado (Tecnovigilância) - GE ...
# 3515                                        Alerta 1788
# 3516                                        Alerta 1787
# 3517                                        Alerta 1780
# 3518                                        Alerta 1779
#
#                                                     url  \
# 0     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 1     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 2     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3     http://antigo.anvisa.gov.br/informacoes-tecnic...
# 4     http://antigo.anvisa.gov.br/informacoes-tecnic...
# ...                                                 ...
# 3514  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3515  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3516  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3517  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3518  http://antigo.anvisa.gov.br/informacoes-tecnic...
#
#                                                 content
# 0        Área:  GGMON    Número:  5265   Ano:  2026 ...
# 1        Área:  GGMON    Número:  5264   Ano:  2026 ...
# 2        Área:  GGMON    Número:  5263   Ano:  2026 ...
# 3        Área:  GGMON    Número:  5262   Ano:  2026 ...
# 4        Área:  GGMON    Número:  5261   Ano:  2026 ...
# ...                                                 ...
# 3514     Área:  GGMON    Número:  1789   Ano:  2016 ...
# 3515     Área:  GGMON    Número:  1788   Ano:  2016 ...
# 3516     Área:  GGMON    Número:  1787   Ano:  2016 ...
# 3517     Área:  GGMON    Número:  1780   Ano:  2016 ...
# 3518     Área:  GGMON    Número:  1779   Ano:  2016 ...
#
# [3519 rows x 3 columns]

# %%
duplicateRows_content = df[df.duplicated(['content'])]

# %%
duplicateRows_titulo = df[df.duplicated(['titulo'])]
duplicateRows_titulo
# Out:
#                                                  titulo  \
# 1070  Alerta 4227 (Tecnovigilância) - Comunicado da ...
# 1800  ALERTA: Anvisa alerta os profissionais de saúd...
# 3368  Siemens - Sistema de Ultrassom Diagnóstico ACU...
#
#                                                     url  \
# 1070  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 1800  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3368  http://antigo.anvisa.gov.br/informacoes-tecnic...
#
#                                                 content
# 1070     Área:  GGMON    Número:  4227   Ano:  2023 ...
# 1800     Área:  GGMON    Número:  142021   Ano:  202...
# 3368     Área:  GGMON    Número:  1964   Ano:  2016 ...

# %%
dupes = []
for titulo in duplicateRows_titulo['titulo']:
    dupes.append(df.query('titulo == "' + titulo + '"')[['titulo', 'url', 'content']])

# %%
dupes[0]
# Out:
#                                                  titulo  \
# 1069  Alerta 4227 (Tecnovigilância) - Comunicado da ...
# 1070  Alerta 4227 (Tecnovigilância) - Comunicado da ...
#
#                                                     url  \
# 1069  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 1070  http://antigo.anvisa.gov.br/informacoes-tecnic...
#
#                                                 content
# 1069     Área:  GGMON    Número:  4227   Ano:  2023 ...
# 1070     Área:  GGMON    Número:  4227   Ano:  2023 ...

# %%
dupes[1]
# Out:
#                                                  titulo  \
# 1744  ALERTA: Anvisa alerta os profissionais de saúd...
# 1800  ALERTA: Anvisa alerta os profissionais de saúd...
#
#                                                     url  \
# 1744  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 1800  http://antigo.anvisa.gov.br/informacoes-tecnic...
#
#                                                 content
# 1744     Área:  GGMON    Número:  62021   Ano:  2021...
# 1800     Área:  GGMON    Número:  142021   Ano:  202...

# %%
dupes[2]
# Out:
#                                                  titulo  \
# 3367  Siemens - Sistema de Ultrassom Diagnóstico ACU...
# 3368  Siemens - Sistema de Ultrassom Diagnóstico ACU...
#
#                                                     url  \
# 3367  http://antigo.anvisa.gov.br/informacoes-tecnic...
# 3368  http://antigo.anvisa.gov.br/informacoes-tecnic...
#
#                                                 content
# 3367     Área:  GGMON    Número:  1965   Ano:  2016 ...
# 3368     Área:  GGMON    Número:  1964   Ano:  2016 ...

# %%
df.to_csv(DATASET_FILEPATH, index=False, encoding='utf-8')
